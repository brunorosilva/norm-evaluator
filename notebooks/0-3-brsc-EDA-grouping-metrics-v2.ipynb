# %% [markdown]
# # Exploratory Data Analysis - Grouping Metrics
# This notebook is focused on creating a metric to make sure that products are being correctly categorized.
#
# Naming convention is a number (for ordering), the creator's initials, and a short `-` delimited description. [source](https://cookiecutter-data-science.drivendata.org/)

# %%
import os
import json
import numpy as np

# %%
# !ls ../examples/model_outputs/
# Out:
# 2.json	4.json	5.json	7.json

# %%
# !ls ../examples/ground_truth/
# Out:
# example_01.json  example_05.json  example_09.json  example_13.json
# example_02.json  example_06.json  example_10.json
# example_03.json  example_07.json  example_11.json
# example_04.json  example_08.json  example_12.json

# %%
data = {}
for model in os.listdir("../examples/model_outputs/"):
    with open(f"../examples/model_outputs/{model}", 'r') as f:
        data[f'model_{model.split(".json")[0]}'] = json.load(f)

# %%
data
# Out:
# {'model_4': {'estimate_preds': [{'valid_file_name': 'example_01',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 74.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 18.5,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Floor Tile',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Tub/Shower Combo',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Vanity',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Toilet',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Light Fixtures',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Floor Tile - 12x24 Porcelain',
#       'qty': 74.0,
#       'uom': 'SF',
#       'rateUsd': 8.0,
#       'rowTotalCostUsd': 592.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Wall Tile - 3x6 Subway',
#       'qty': 148.0,
#       'uom': 'SF',
#       'rateUsd': 8.0,
#       'rowTotalCostUsd': 1184.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Waterproofing Membrane',
#       'qty': 222.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 555.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Mortar',
#       'qty': 150.0,
#       'uom': 'LB',
#       'rateUsd': 0.2,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Grout',
#       'qty': 1.0,
#       'uom': 'GAL',
#       'rateUsd': 40.0,
#       'rowTotalCostUsd': 40.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Spacers',
#       'qty': 3.0,
#       'uom': 'BOX',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Installation Labor',
#       'qty': 23.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 1725.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Niche Insert',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 75.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Curb Material',
#       'qty': 3.0,
#       'uom': 'LF',
#       'rateUsd': 25.0,
#       'rowTotalCostUsd': 75.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Pan Pre-Slope Material',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 45.0,
#       'rowTotalCostUsd': 45.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Pan Installation Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 74.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 22.2,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall and Ceiling Surfaces for Paint',
#       'qty': 259.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 77.7,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 4.0,
#       'uom': 'GAL',
#       'rateUsd': 55.0,
#       'rowTotalCostUsd': 220.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 3.7,
#       'rowTotalCostUsd': 3.7,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Double Vanity Cabinet',
#       'qty': 5.0,
#       'uom': 'LF',
#       'rateUsd': 300.0,
#       'rowTotalCostUsd': 1500.0,
#       'category': 'material',
#       'sectionName': 'Cabinets',
#       'metadata': None},
#      {'label': 'Cabinet Installation Labor',
#       'qty': 5.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 325.0,
#       'category': 'labor',
#       'sectionName': 'Cabinets',
#       'metadata': None},
#      {'label': 'Shower Faucet Set',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 250.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Drain',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Double Vanity Faucet Set',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 500.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Vanity Sink Drain',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 100.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Toilet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 250.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PEX Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 0.7,
#       'rowTotalCostUsd': 21.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PVC Drain Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 1.0,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Pipe Fittings and Adhesives',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 75.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Finish',
#       'qty': 10.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 850.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Bathroom Light Fixtures',
#       'qty': 4.0,
#       'uom': 'EA',
#       'rateUsd': 150.0,
#       'rowTotalCostUsd': 600.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'GFCI Outlets',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 30.0,
#       'rowTotalCostUsd': 60.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Light Switches',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 30.0,
#       'rowTotalCostUsd': 60.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Electrical Labor',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 680.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None}],
#     'time_to_estimate_sec': 30.1317777633667},
#    {'valid_file_name': 'example_03',
#     'rows': [{'label': 'Mask Off and Protect Work Area',
#       'qty': 1000.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall Surfaces for Paint',
#       'qty': 2500.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 750.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Ceiling Surfaces for Paint',
#       'qty': 1000.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 18.0,
#       'uom': 'GAL',
#       'rateUsd': 36.85,
#       'rowTotalCostUsd': 663.3000000000001,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': {'gradeIndex': 0.67}},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 10.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 650.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None}],
#     'time_to_estimate_sec': 123.15671801567078},
#    {'valid_file_name': 'example_03',
#     'rows': [{'label': 'Mask Off and Protect Work Area',
#       'qty': 1000.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall Surfaces for Paint',
#       'qty': 2500.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 750.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Ceiling Surfaces for Paint',
#       'qty': 1000.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 35.0,
#       'uom': 'GAL',
#       'rateUsd': 36.85,
#       'rowTotalCostUsd': 1289.75,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': {'gradeIndex': 0.67}},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 10.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 650.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None}],
#     'time_to_estimate_sec': 123.38567519187927},
#    {'valid_file_name': 'example_02',
#     'rows': [{'label': 'R-13 Sound Insulation Batts',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 1.2,
#       'rowTotalCostUsd': 240.0,
#       'category': 'material',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': 'Insulation Installation Labor',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': '1/2 inch Drywall for Walls',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 0.6,
#       'rowTotalCostUsd': 120.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Premixed Joint Compound',
#       'qty': 2.0,
#       'uom': 'GAL',
#       'rateUsd': 5.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Texture',
#       'qty': 2.0,
#       'uom': 'GAL',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 20.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Tape',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 5.0,
#       'rowTotalCostUsd': 5.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Labor (Hang, Tape, and Finish)',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 60.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall Surface for Paint',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 60.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 1.0,
#       'uom': 'GAL',
#       'rateUsd': 55.0,
#       'rowTotalCostUsd': 55.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None}],
#     'time_to_estimate_sec': 123.61094665527344},
#    {'valid_file_name': 'example_02',
#     'rows': [{'label': 'R-13 Sound Insulation Batts',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 1.2,
#       'rowTotalCostUsd': 240.0,
#       'category': 'material',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': 'Insulation Installation Labor',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': '1/2 inch Drywall for Walls',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 0.6,
#       'rowTotalCostUsd': 120.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Premixed Joint Compound',
#       'qty': 2.0,
#       'uom': 'GAL',
#       'rateUsd': 5.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Tape',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 5.0,
#       'rowTotalCostUsd': 5.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Labor (Hang, Tape, and Finish)',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 60.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall Surface for Paint',
#       'qty': 200.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 60.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 1.0,
#       'uom': 'GAL',
#       'rateUsd': 55.0,
#       'rowTotalCostUsd': 55.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None}],
#     'time_to_estimate_sec': 124.77875995635986},
#    {'valid_file_name': 'example_01',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 74.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 18.5,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Floor Tile',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Tub',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Vanity',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Toilet',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Lighting Fixtures',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Shower Walls',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Floor Tile (12x24 Porcelain)',
#       'qty': 74.0,
#       'uom': 'SF',
#       'rateUsd': 8.0,
#       'rowTotalCostUsd': 592.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Wall Tile (3x6 Subway)',
#       'qty': 148.0,
#       'uom': 'SF',
#       'rateUsd': 8.0,
#       'rowTotalCostUsd': 1184.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Waterproofing Membrane',
#       'qty': 222.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 555.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Mortar',
#       'qty': 150.0,
#       'uom': 'LB',
#       'rateUsd': 0.2,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Grout',
#       'qty': 1.0,
#       'uom': 'GAL',
#       'rateUsd': 40.0,
#       'rowTotalCostUsd': 40.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Spacers',
#       'qty': 3.0,
#       'uom': 'EA',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Installation Labor',
#       'qty': 23.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 1725.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Niche',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 75.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Curb Material',
#       'qty': 3.0,
#       'uom': 'LF',
#       'rateUsd': 25.0,
#       'rowTotalCostUsd': 75.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 74.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 22.2,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall and Ceiling Surfaces for Paint',
#       'qty': 354.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 106.2,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 6.0,
#       'uom': 'GAL',
#       'rateUsd': 55.0,
#       'rowTotalCostUsd': 330.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 3.7,
#       'rowTotalCostUsd': 3.7,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Double Vanity Cabinet',
#       'qty': 5.0,
#       'uom': 'LF',
#       'rateUsd': 300.0,
#       'rowTotalCostUsd': 1500.0,
#       'category': 'material',
#       'sectionName': 'Cabinets',
#       'metadata': None},
#      {'label': 'Cabinet Installation Labor',
#       'qty': 5.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 325.0,
#       'category': 'labor',
#       'sectionName': 'Cabinets',
#       'metadata': None},
#      {'label': 'Shower Faucet Set',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 250.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Drain',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Double Vanity Sink',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 800.0,
#       'rowTotalCostUsd': 800.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Vanity Faucet Set',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 500.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Sink Drain',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 100.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Toilet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 250.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PEX Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 0.7,
#       'rowTotalCostUsd': 21.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PVC Drain Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 1.0,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Pipe Fittings and Adhesives',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 100.0,
#       'rowTotalCostUsd': 100.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Finish',
#       'qty': 10.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 850.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Pan',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 350.0,
#       'rowTotalCostUsd': 350.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Pan Installation',
#       'qty': 3.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 255.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Remove Existing Light Fixtures',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'New Bathroom Light Fixtures',
#       'qty': 4.0,
#       'uom': 'EA',
#       'rateUsd': 150.0,
#       'rowTotalCostUsd': 600.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Install New Light Fixtures',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Electrical Supplies',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None}],
#     'time_to_estimate_sec': 127.02065801620483},
#    {'valid_file_name': 'example_04',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 70.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 17.5,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Bathtub',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Wall Materials for Shower Area',
#       'qty': 3.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 195.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Shower Wall Tile Installation',
#       'qty': 16.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 1200.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Bathroom Floor Tile Installation',
#       'qty': 7.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 525.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Bench Installation',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 150.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Installation Materials',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 285.0,
#       'rowTotalCostUsd': 285.0,
#       'category': 'ensemble materials',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Membrane',
#       'qty': 170.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 425.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Mortar',
#       'qty': 100.0,
#       'uom': 'LB',
#       'rateUsd': 0.2,
#       'rowTotalCostUsd': 20.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Spacers',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 20.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Pan Installation',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 350.0,
#       'rowTotalCostUsd': 350.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Drain Assembly',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PVC Drain Piping',
#       'qty': 10.0,
#       'uom': 'LF',
#       'rateUsd': 1.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Pipe Fittings and Adhesives',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Rough In and Finish',
#       'qty': 6.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 510.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Cement Board Installation - Shower Walls',
#       'qty': 64.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 160.0,
#       'category': 'material',
#       'sectionName': 'Construction',
#       'metadata': None},
#      {'label': 'Cement Board Installation Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Construction',
#       'metadata': None},
#      {'label': 'Waterproofing Membrane - Shower',
#       'qty': 64.0,
#       'uom': 'SF',
#       'rateUsd': 3.0,
#       'rowTotalCostUsd': 192.0,
#       'category': 'material',
#       'sectionName': 'Construction',
#       'metadata': None},
#      {'label': 'Waterproofing Installation Labor',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Construction',
#       'metadata': None}],
#     'time_to_estimate_sec': 119.80275201797485},
#    {'valid_file_name': 'example_04',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 70.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 17.5,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Bathtub',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Wall Materials for Shower Area',
#       'qty': 3.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 195.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Shower Wall Tile Installation',
#       'qty': 100.0,
#       'uom': 'SF',
#       'rateUsd': 8.5,
#       'rowTotalCostUsd': 850.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Bathroom Floor Tile Installation',
#       'qty': 70.0,
#       'uom': 'SF',
#       'rateUsd': 7.5,
#       'rowTotalCostUsd': 525.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Waterproofing Membrane',
#       'qty': 170.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 425.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Mortar',
#       'qty': 100.0,
#       'uom': 'LB',
#       'rateUsd': 0.2,
#       'rowTotalCostUsd': 20.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Spacers',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 20.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Floor Preparation',
#       'qty': 70.0,
#       'uom': 'SF',
#       'rateUsd': 3.0,
#       'rowTotalCostUsd': 210.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Cement Board Installation - Shower Walls',
#       'qty': 100.0,
#       'uom': 'SF',
#       'rateUsd': 3.5,
#       'rowTotalCostUsd': 350.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Cement Board Materials',
#       'qty': 100.0,
#       'uom': 'SF',
#       'rateUsd': 2.0,
#       'rowTotalCostUsd': 200.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Curb Installation',
#       'qty': 3.0,
#       'uom': 'LF',
#       'rateUsd': 45.0,
#       'rowTotalCostUsd': 135.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Curb Materials',
#       'qty': 3.0,
#       'uom': 'LF',
#       'rateUsd': 15.0,
#       'rowTotalCostUsd': 45.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Shower Pan Installation',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 350.0,
#       'rowTotalCostUsd': 350.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Drain Assembly',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PVC Drain Piping',
#       'qty': 10.0,
#       'uom': 'LF',
#       'rateUsd': 1.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Pipe Fittings and Adhesives',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Shower Pan and Drain Installation',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 340.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Existing Shower Faucet Reconnection',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 170.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Install Shower Bench',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 150.0,
#       'category': 'labor',
#       'sectionName': 'Specialties',
#       'metadata': None}],
#     'time_to_estimate_sec': 146.75845074653625},
#    {'valid_file_name': 'example_06',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 93.75,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Crown Molding',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Remove Light Trims and Vents',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Ceiling Drywall',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'R-19 Sound Insulation Batts',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 1.2,
#       'rowTotalCostUsd': 450.0,
#       'category': 'material',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': 'Insulation Installation Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': 'Quiet Rock Drywall 5/8" (4\'x8\' sheets)',
#       'qty': 12.0,
#       'uom': 'EA',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 780.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Resilient Channel',
#       'qty': 150.0,
#       'uom': 'LF',
#       'rateUsd': 1.5,
#       'rowTotalCostUsd': 225.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Screws',
#       'qty': 10.0,
#       'uom': 'LB',
#       'rateUsd': 3.5,
#       'rowTotalCostUsd': 35.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Joint Compound',
#       'qty': 4.0,
#       'uom': 'GAL',
#       'rateUsd': 15.0,
#       'rowTotalCostUsd': 60.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Tape',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 5.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Labor (Install Resilient Channel, Hang Quiet Rock, Tape, and Finish)',
#       'qty': 24.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 1800.0,
#       'category': 'labor',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Crown Molding Material',
#       'qty': 85.0,
#       'uom': 'LF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 212.5,
#       'category': 'material',
#       'sectionName': 'Trim',
#       'metadata': None},
#      {'label': 'Crown Molding Installation Labor',
#       'qty': 5.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 325.0,
#       'category': 'labor',
#       'sectionName': 'Trim',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 112.5,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Ceiling Surfaces for Paint',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 112.5,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 2.0,
#       'uom': 'GAL',
#       'rateUsd': 55.0,
#       'rowTotalCostUsd': 110.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 18.8,
#       'rowTotalCostUsd': 18.8,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Reinstall Light Trims',
#       'qty': 8.0,
#       'uom': 'EA',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Reinstall Vents',
#       'qty': 4.0,
#       'uom': 'EA',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Electrical Wiring Inspection and Adjustment',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 170.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None}],
#     'time_to_estimate_sec': 143.78464102745056},
#    {'valid_file_name': 'example_06',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 93.75,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Crown Molding',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Remove Light Trims and Vents',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Ceiling Drywall',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'R-19 Sound Insulation Batts for Ceiling',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 1.2,
#       'rowTotalCostUsd': 450.0,
#       'category': 'material',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': 'Insulation Installation Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'Insulation',
#       'metadata': None},
#      {'label': 'Quiet Rock Drywall (5/8" thick)',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 937.5,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Resilient Channel',
#       'qty': 210.0,
#       'uom': 'LF',
#       'rateUsd': 1.8,
#       'rowTotalCostUsd': 378.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Screws',
#       'qty': 10.0,
#       'uom': 'LB',
#       'rateUsd': 3.5,
#       'rowTotalCostUsd': 35.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Joint Compound',
#       'qty': 4.0,
#       'uom': 'GAL',
#       'rateUsd': 12.0,
#       'rowTotalCostUsd': 48.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Tape',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 5.0,
#       'rowTotalCostUsd': 5.0,
#       'category': 'material',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Drywall Labor (Install Resilient Channel, Hang Quiet Rock, Tape, and Finish)',
#       'qty': 20.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 1500.0,
#       'category': 'labor',
#       'sectionName': 'Drywall',
#       'metadata': None},
#      {'label': 'Crown Molding Material',
#       'qty': 85.0,
#       'uom': 'LF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 212.5,
#       'category': 'material',
#       'sectionName': 'Trim',
#       'metadata': None},
#      {'label': 'Crown Molding Installation Labor',
#       'qty': 5.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 325.0,
#       'category': 'labor',
#       'sectionName': 'Trim',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 112.5,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Ceiling Surfaces for Paint',
#       'qty': 375.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 112.5,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint - Sherwin Williams Duration Line',
#       'qty': 2.0,
#       'uom': 'GAL',
#       'rateUsd': 55.0,
#       'rowTotalCostUsd': 110.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 18.8,
#       'rowTotalCostUsd': 18.8,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Reinstall Light Trims',
#       'qty': 8.0,
#       'uom': 'EA',
#       'rateUsd': 35.0,
#       'rowTotalCostUsd': 280.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Reinstall Vents',
#       'qty': 4.0,
#       'uom': 'EA',
#       'rateUsd': 45.0,
#       'rowTotalCostUsd': 180.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Electrical Labor',
#       'qty': 6.0,
#       'uom': 'HRS',
#       'rateUsd': 85.0,
#       'rowTotalCostUsd': 510.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None}],
#     'time_to_estimate_sec': 145.92942118644714},
#    {'valid_file_name': 'example_05',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 70.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 17.5,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Set Up Air Filter',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Floor Tile',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Shower Wall Tile',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Tub',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Vanity',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Plumbing Fixtures',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Lighting Fixtures',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'material',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': '12x24 Porcelain Floor Tile',
#       'qty': 70.0,
#       'uom': 'SF',
#       'rateUsd': 12.96,
#       'rowTotalCostUsd': 907.2,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': '3x6 Subway Shower Wall Tile',
#       'qty': 140.0,
#       'uom': 'SF',
#       'rateUsd': 12.96,
#       'rowTotalCostUsd': 1814.4,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Tile Membrane',
#       'qty': 210.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
# ...
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Bathroom Vanity Cabinet',
#       'qty': 4.0,
#       'uom': 'LF',
#       'rateUsd': 486.0,
#       'rowTotalCostUsd': 1944.0,
#       'category': 'material',
#       'sectionName': 'Cabinets',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Medicine Cabinet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 324.0,
#       'rowTotalCostUsd': 324.0,
#       'category': 'material',
#       'sectionName': 'Cabinets',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Cabinet Installation Labor',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 600.0,
#       'category': 'labor',
#       'sectionName': 'Cabinets',
#       'metadata': None},
#      {'label': 'Shower Faucet Set',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 250.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Drain',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Toilet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 250.0,
#       'rowTotalCostUsd': 250.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Bidet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 520.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PEX Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 0.7,
#       'rowTotalCostUsd': 21.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PVC Drain Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 1.0,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Rough In and Finish',
#       'qty': 13.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 845.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Rough Electrical Wiring',
#       'qty': 56.0,
#       'uom': 'LF',
#       'rateUsd': 0.5,
#       'rowTotalCostUsd': 28.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'GFCI Outlets',
#       'qty': 4.0,
#       'uom': 'EA',
#       'rateUsd': 30.0,
#       'rowTotalCostUsd': 120.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Light Switches',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 30.0,
#       'rowTotalCostUsd': 60.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Ceiling Lights',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 1231.2,
#       'rowTotalCostUsd': 2462.4,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Exhaust Fan Wiring',
#       'qty': 10.0,
#       'uom': 'LF',
#       'rateUsd': 0.5,
#       'rowTotalCostUsd': 5.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Electrical Labor',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Exhaust Fan Material',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 200.0,
#       'rowTotalCostUsd': 200.0,
#       'category': 'material',
#       'sectionName': 'HVAC',
#       'metadata': None},
#      {'label': 'Exhaust Fan Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 300.0,
#       'category': 'labor',
#       'sectionName': 'HVAC',
#       'metadata': None},
#      {'label': 'Mirror',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 405.0,
#       'rowTotalCostUsd': 405.0,
#       'category': 'material',
#       'sectionName': 'Specialties',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Wallpaper',
#       'qty': 250.0,
#       'uom': 'SF',
#       'rateUsd': 6.0,
#       'rowTotalCostUsd': 1500.0,
#       'category': 'labor plus material',
#       'sectionName': 'Specialties',
#       'metadata': None}],
#     'time_to_estimate_sec': 33.386852979660034},
#    {'valid_file_name': 'example_13',
#     'rows': [{'label': 'Protect Work Area and Surroundings',
#       'qty': 56.0,
#       'uom': 'SF',
#       'rateUsd': 0.25,
#       'rowTotalCostUsd': 14.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Tub',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Wall Tile',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 520.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Shower Fixtures',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Vanity',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Lights',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Medicine Cabinet',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Mirror',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Toilet',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Demo Exhaust Fan',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 65.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Disposal Costs',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 400.0,
#       'rowTotalCostUsd': 400.0,
#       'category': 'labor',
#       'sectionName': 'Demolition',
#       'metadata': None},
#      {'label': 'Pocket Door (Material and Install) x2',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 600.0,
#       'rowTotalCostUsd': 1200.0,
#       'category': 'labor plus material',
#       'sectionName': 'Doors',
#       'metadata': None},
#      {'label': 'Sliding Shower Door (Material and Install)',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 1000.0,
#       'rowTotalCostUsd': 1000.0,
#       'category': 'labor plus material',
#       'sectionName': 'Doors',
#       'metadata': None},
#      {'label': 'Tub Wall Tile',
#       'qty': 92.0,
#       'uom': 'SF',
#       'rateUsd': 12.96,
#       'rowTotalCostUsd': 1192.3200000000002,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Membrane',
#       'qty': 92.0,
#       'uom': 'SF',
#       'rateUsd': 2.5,
#       'rowTotalCostUsd': 230.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Mortar',
#       'qty': 50.0,
#       'uom': 'LB',
#       'rateUsd': 0.2,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Grout',
#       'qty': 1.0,
#       'uom': 'GAL',
#       'rateUsd': 40.0,
#       'rowTotalCostUsd': 40.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Spacers',
#       'qty': 1.0,
#       'uom': 'BOX',
#       'rateUsd': 10.0,
#       'rowTotalCostUsd': 10.0,
#       'category': 'material',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Tile Installation Labor',
#       'qty': 9.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 585.0,
#       'category': 'labor',
#       'sectionName': 'Tile',
#       'metadata': None},
#      {'label': 'Baseboard',
#       'qty': 25.0,
#       'uom': 'LF',
#       'rateUsd': 4.05,
#       'rowTotalCostUsd': 101.25,
#       'category': 'material',
#       'sectionName': 'Trim',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Baseboard Installation',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 130.0,
#       'category': 'labor',
#       'sectionName': 'Trim',
#       'metadata': None},
#      {'label': 'Mask Off and Protect Work Area',
#       'qty': 56.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 16.8,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Wall Surfaces for Paint',
#       'qty': 140.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 42.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Prepare Ceiling Surfaces for Paint',
#       'qty': 56.0,
#       'uom': 'SF',
#       'rateUsd': 0.3,
#       'rowTotalCostUsd': 16.8,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Finish Paint (Sherwin Williams Duration Line)',
#       'qty': 1.0,
#       'uom': 'GAL',
#       'rateUsd': 89.1,
#       'rowTotalCostUsd': 89.1,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Painting Supplies and Consumables',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Painting Labor',
#       'qty': 4.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 260.0,
#       'category': 'labor',
#       'sectionName': 'Painting',
#       'metadata': None},
#      {'label': 'Bathroom Vanity Cabinet',
#       'qty': 4.0,
#       'uom': 'LF',
#       'rateUsd': 486.0,
#       'rowTotalCostUsd': 1944.0,
#       'category': 'material',
#       'sectionName': 'Cabinets',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Medicine Cabinet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 324.0,
#       'rowTotalCostUsd': 324.0,
#       'category': 'material',
#       'sectionName': 'Cabinets',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Cabinet Installation Labor',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 600.0,
#       'category': 'labor',
#       'sectionName': 'Cabinets',
#       'metadata': None},
#      {'label': 'Bathtub Insert',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 500.0,
#       'rowTotalCostUsd': 500.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Shower Faucet Set',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 405.0,
#       'rowTotalCostUsd': 405.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Shower Drain',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Toilet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 405.0,
#       'rowTotalCostUsd': 405.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Bidet',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 842.4,
#       'rowTotalCostUsd': 842.4,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'PEX Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 0.7,
#       'rowTotalCostUsd': 21.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'PVC Drain Piping',
#       'qty': 30.0,
#       'uom': 'LF',
#       'rateUsd': 1.0,
#       'rowTotalCostUsd': 30.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Pipe Fittings and Adhesives',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 50.0,
#       'rowTotalCostUsd': 50.0,
#       'category': 'material',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Plumbing Labor - Rough In and Finish',
#       'qty': 13.0,
#       'uom': 'HRS',
#       'rateUsd': 100.0,
#       'rowTotalCostUsd': 1300.0,
#       'category': 'labor',
#       'sectionName': 'Plumbing',
#       'metadata': None},
#      {'label': 'Rough Electrical Wiring',
#       'qty': 56.0,
#       'uom': 'LF',
#       'rateUsd': 0.5,
#       'rowTotalCostUsd': 28.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'GFCI Outlets',
#       'qty': 4.0,
#       'uom': 'EA',
#       'rateUsd': 30.0,
#       'rowTotalCostUsd': 120.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Light Switches',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 30.0,
#       'rowTotalCostUsd': 60.0,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Ceiling Lights',
#       'qty': 2.0,
#       'uom': 'EA',
#       'rateUsd': 1231.2,
#       'rowTotalCostUsd': 2462.4,
#       'category': 'material',
#       'sectionName': 'Electrical',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Electrical Labor',
#       'qty': 9.0,
#       'uom': 'HRS',
#       'rateUsd': 65.0,
#       'rowTotalCostUsd': 585.0,
#       'category': 'labor',
#       'sectionName': 'Electrical',
#       'metadata': None},
#      {'label': 'Shower Wall Niche Material',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 405.0,
#       'rowTotalCostUsd': 405.0,
#       'category': 'material',
#       'sectionName': 'Specialties',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Shower Wall Niche Labor',
#       'qty': 2.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 150.0,
#       'category': 'labor',
#       'sectionName': 'Specialties',
#       'metadata': None},
#      {'label': 'Mirror Material',
#       'qty': 1.0,
#       'uom': 'EA',
#       'rateUsd': 324.0,
#       'rowTotalCostUsd': 324.0,
#       'category': 'material',
#       'sectionName': 'Specialties',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Mirror Labor',
#       'qty': 1.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 75.0,
#       'category': 'labor',
#       'sectionName': 'Specialties',
#       'metadata': None},
#      {'label': 'Wallpaper Material',
#       'qty': 250.0,
#       'uom': 'SF',
#       'rateUsd': 9.72,
#       'rowTotalCostUsd': 2430.0,
#       'category': 'material',
#       'sectionName': 'Specialties',
#       'metadata': {'gradeIndex': 1.62}},
#      {'label': 'Wallpaper Labor',
#       'qty': 8.0,
#       'uom': 'HRS',
#       'rateUsd': 75.0,
#       'rowTotalCostUsd': 600.0,
#       'category': 'labor',
#       'sectionName': 'Specialties',
#       'metadata': None}],
#     'time_to_estimate_sec': 40.77487516403198}]}}

# %%
data.keys()
# Out:
# dict_keys(['model_4', 'model_7', 'model_5', 'model_2'])

# %%
gt_data = {}
for fn in os.listdir("../examples/ground_truth/"):
    with open(f"../examples/ground_truth/{fn}", 'r') as f:
        gt_data[fn.split('.json')[0]] = json.load(f)

# %%
gt_data.keys()
# Out:
# dict_keys(['example_08', 'example_11', 'example_09', 'example_03', 'example_05', 'example_06', 'example_13', 'example_12', 'example_07', 'example_10', 'example_02', 'example_01', 'example_04'])

# %% [markdown]
# ### Grouping Metrics
#
# Using LLAMA 3.1 was too getting very slow, so I've decided to create a new metric to make it easier for deployment

# %%
product_grouping_template = """
Category of product {}
"""

labor_grouping_template = """
Category of labor {}
"""

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim
model = SentenceTransformer('all-mpnet-base-v2')
s1 = labor_grouping_template.format("Protect Work Area and Surroundings")
s2 = "Demolition"
cos_sim(model.encode(s1), model.encode(s2))
# Out:
# tensor([[0.1949]])

# %%
s1 = labor_grouping_template.format("Lay down all day")
s2 = "Demolition"
cos_sim(model.encode(s1), model.encode(s2))
# Out:
# tensor([[0.1654]])

# %%
s1 = labor_grouping_template.format('Demo Floor Tile')
s2 = "Demolition"
cos_sim(model.encode(s1), model.encode(s2))
# Out:
# tensor([[0.3404]])

# %% [markdown]
# Some improvements could be made using better prompting and a better model.

# %%
s1 = product_grouping_template.format("Floor Tile - 12x24 Porcelain")
s2 = "Tile"
cos_sim(model.encode(s1), model.encode(s2))
# Out:
# tensor([[0.6231]])

# %%
s1 = product_grouping_template.format("Protect Work Area and Surroundings")
s2 = "Tile"
cos_sim(model.encode(s1), model.encode(s2))
# Out:
# tensor([[0.0998]])

# %% [markdown]
# Works fine for the purpose of this challenge.
